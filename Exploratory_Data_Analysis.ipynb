# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/storage/emulated/0/Documents/Pydroid3/Case_Information.csv')
df
# Out:
#        case_id   age age_group     sex date_announced date_recovered  \
# 0      C404174  38.0  35 to 39  Female     2020-01-30            NaN
# 1      C462688  44.0  40 to 44    Male     2020-02-03            NaN
# 2      C387710  60.0  60 to 64  Female     2020-02-05     2020-01-31
# 3      C377460  48.0  45 to 49    Male     2020-03-06            NaN
# 4      C498051  62.0  60 to 64    Male     2020-03-06            NaN
# ...        ...   ...       ...     ...            ...            ...
# 12086  C972617  35.0  35 to 39    Male     2020-05-15            NaN
# 12087  C975669  37.0  35 to 39    Male     2020-05-15            NaN
# 12088  C980530  62.0  60 to 64  Female     2020-05-15            NaN
# 12089  C987431  18.0  15 to 19  Female     2020-05-15            NaN
# 12090  C995671  50.0  50 to 54  Female     2020-05-15            NaN
#
#       date_of_death            status date_announced_as_removed  \
# 0               NaN         Recovered                2020-02-07
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df
# Out:
#        case_id   age age_group     sex date_announced date_recovered  \
# 0      C404174 38.00  35 to 39  Female     2020-01-30            NaN
# 1      C462688 44.00  40 to 44    Male     2020-02-03            NaN
# 2      C387710 60.00  60 to 64  Female     2020-02-05     2020-01-31
# 3      C377460 48.00  45 to 49    Male     2020-03-06            NaN
# 4      C498051 62.00  60 to 64    Male     2020-03-06            NaN
# ...        ...   ...       ...     ...            ...            ...
# 12086  C972617 35.00  35 to 39    Male     2020-05-15            NaN
# 12087  C975669 37.00  35 to 39    Male     2020-05-15            NaN
# 12088  C980530 62.00  60 to 64  Female     2020-05-15            NaN
# 12089  C987431 18.00  15 to 19  Female     2020-05-15            NaN
# 12090  C995671 50.00  50 to 54  Female     2020-05-15            NaN
#
#       date_of_death            status date_announced_as_removed  \
# 0               NaN         Recovered                2020-02-07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12091 entries, 0 to 12090
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   case_id                    12091 non-null  object
#  1   age                        12070 non-null  float64
#  2   age_group                  12070 non-null  object
#  3   sex                        12091 non-null  object
#  4   date_announced             12091 non-null  object
#  5   date_recovered             1237 non-null   object
#  6   date_of_death              657 non-null    object
#  7   status                     12091 non-null  object
#  8   date_announced_as_removed  3266 non-null   object
#  9   province                   11053 non-null  object
#  10  muni_city                  11053 non-null  object
#  11  health_status              12091 non-null  object
#  12  home_quarantined           5310 non-null   object
# ...

# %%
df.describe()
# Out:
#            age
# count 12070.00
# mean     44.38
# std      18.23
# min       0.00
# 25%      30.00
# 50%      43.00
# 75%      58.00
# max     101.00

# %%
df.isnull().sum()
# Out:
# case_id                          0
# age                             21
# age_group                       21
# sex                              0
# date_announced                   0
# date_recovered               10854
# date_of_death                11434
# status                           0
# date_announced_as_removed     8825
# province                      1038
# muni_city                     1038
# health_status                    0
# home_quarantined              6781
# date_of_onset_of_symptoms     5530
# pregnant                     10166
# region                        1038
# dtype: int64

# %%
df.nunique()
# Out:
# case_id                      12090
# age                            100
# age_group                       17
# sex                              2
# date_announced                  74
# date_recovered                  62
# date_of_death                   63
# status                           5
# date_announced_as_removed       68
# province                        61
# muni_city                      363
# health_status                    6
# home_quarantined                 2
# date_of_onset_of_symptoms       96
# pregnant                         2
# region                          17
# dtype: int64

# %%
df.sort_values(by='age', ascending=False).head(10)
# Out:
#        case_id    age age_group     sex date_announced date_recovered  \
# 3583   C827192 101.00       80+    Male     2020-04-06            NaN
# 11158  C364378  99.00       80+    Male     2020-05-12            NaN
# 1351   C845939  99.00       80+    Male     2020-03-29            NaN
# 9423   C810967  99.00       80+  Female     2020-05-04            NaN
# 3962   C474713  97.00       80+  Female     2020-04-09            NaN
# 8561   C302444  96.00       80+  Female     2020-05-01            NaN
# 757    C521779  96.00       80+    Male     2020-03-27            NaN
# 6238   C875837  96.00       80+  Female     2020-04-19            NaN
# 12038  C782011  95.00       80+  Female     2020-05-15            NaN
# 4700   C280584  95.00       80+  Female     2020-04-13            NaN
#
#       date_of_death          status date_announced_as_removed  \
# 3583            NaN  For validation                       NaN
# 11158    2020-05-03            Died                2020-05-12
# ...

# %%
df.groupby('region').mean().sort_values(by='age')
# Out:
#                                               age
# region
# Central Visayas (Region VII)                35.88
# Cagayan Valley (Region II)                  40.12
# Davao Region (Region XI)                    40.82
# Zamboanga Peninsula (Region IX)             42.60
# Eastern Visayas (Region VIII)               43.21
# MIMAROPA (Region IV-B)                      43.54
# CALABARZON (Region IV-A)                    44.45
# Western Visayas (Region VI)                 45.05
# Bicol Region (Region V)                     45.15
# Cordillera Administrative Region (CAR)      45.27
# Central Luzon (Region III)                  45.45
# Metropolitan Manila                         46.73
# Northern Mindanao (Region X)                48.24
# Caraga (Region XIII)                        48.67
# SOCCSKSARGEN (Region XII)                   49.40
# Ilocos Region (Region I)                    51.89
# Autonomous Region of Muslim Mindanao (ARMM) 53.65

# %%
df[df['sex'].str.contains('F')].head(10)
# Out:
#     case_id   age age_group     sex date_announced date_recovered  \
# 0   C404174 38.00  35 to 39  Female     2020-01-30            NaN
# 2   C387710 60.00  60 to 64  Female     2020-02-05     2020-01-31
# 5   C130591 58.00  55 to 59  Female     2020-03-07            NaN
# 10  C261144 68.00  65 to 69  Female     2020-03-09            NaN
# 12  C325527 59.00  55 to 59  Female     2020-03-09     2020-04-06
# 17  C777589 31.00  30 to 34  Female     2020-03-09     2020-03-24
# 19  C817111 47.00  45 to 49  Female     2020-03-09     2020-03-26
# 23  C985840 51.00  50 to 54  Female     2020-03-09            NaN
# 29  C501602 29.00  25 to 29  Female     2020-03-10     2020-03-24
# 30  C766724 83.00       80+  Female     2020-03-10            NaN
#
#    date_of_death     status date_announced_as_removed             province  \
# 0            NaN  Recovered                2020-02-07      Negros Oriental
# 2            NaN  Recovered                2020-02-05                Bohol
# ...

# %%
df.transpose()
# Out:
#                                                   0      \
# case_id                                         C404174
# age                                               38.00
# age_group                                      35 to 39
# sex                                              Female
# date_announced                               2020-01-30
# date_recovered                                      NaN
# date_of_death                                       NaN
# status                                        Recovered
# date_announced_as_removed                    2020-02-07
# province                                Negros Oriental
# muni_city                                Dumaguete City
# health_status                                 Recovered
# home_quarantined                                    NaN
# date_of_onset_of_symptoms                    2020-01-21
# pregnant                                            NaN
# region                     Central Visayas (Region VII)
#
# ...

# %%
df.dtypes
# Out:
# case_id                       object
# age                          float64
# age_group                     object
# sex                           object
# date_announced                object
# date_recovered                object
# date_of_death                 object
# status                        object
# date_announced_as_removed     object
# province                      object
# muni_city                     object
# health_status                 object
# home_quarantined              object
# date_of_onset_of_symptoms     object
# pregnant                      object
# region                        object
# dtype: object

# %%
df.select_dtypes(include='number')
# Out:
#         age
# 0     38.00
# 1     44.00
# 2     60.00
# 3     48.00
# 4     62.00
# ...     ...
# 12086 35.00
# 12087 37.00
# 12088 62.00
# 12089 18.00
# 12090 50.00
#
# [12091 rows x 1 columns]

# %%
df.select_dtypes(include='object')
# Out:
#        case_id age_group     sex date_announced date_recovered date_of_death  \
# 0      C404174  35 to 39  Female     2020-01-30            NaN           NaN
# 1      C462688  40 to 44    Male     2020-02-03            NaN    2020-02-01
# 2      C387710  60 to 64  Female     2020-02-05     2020-01-31           NaN
# 3      C377460  45 to 49    Male     2020-03-06            NaN           NaN
# 4      C498051  60 to 64    Male     2020-03-06            NaN    2020-03-11
# ...        ...       ...     ...            ...            ...           ...
# 12086  C972617  35 to 39    Male     2020-05-15            NaN           NaN
# 12087  C975669  35 to 39    Male     2020-05-15            NaN    2020-05-13
# 12088  C980530  60 to 64  Female     2020-05-15            NaN           NaN
# 12089  C987431  15 to 19  Female     2020-05-15            NaN           NaN
# 12090  C995671  50 to 54  Female     2020-05-15            NaN           NaN
#
# ...

# %%
df.select_dtypes(include='float')
# Out:
#         age
# 0     38.00
# 1     44.00
# 2     60.00
# 3     48.00
# 4     62.00
# ...     ...
# 12086 35.00
# 12087 37.00
# 12088 62.00
# 12089 18.00
# 12090 50.00
#
# [12091 rows x 1 columns]
